# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# import requests
import requests
#get API key
from config import weather_api_key
#Build base url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desciption = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desciption})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | cherskiy
# Processing Record 4 of Set 1 | muros
# Processing Record 5 of Set 1 | dikson
# Processing Record 6 of Set 1 | guerrero negro
# Processing Record 7 of Set 1 | kawana waters
# City not found. Skipping...
# Processing Record 8 of Set 1 | gorom-gorom
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | bonavista
# Processing Record 12 of Set 1 | tra vinh
# Processing Record 13 of Set 1 | along
# Processing Record 14 of Set 1 | tucuman
# Processing Record 15 of Set 1 | east london
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | ahipara
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | bathsheba
# Processing Record 21 of Set 1 | bengkulu
# Processing Record 22 of Set 1 | nanortalik
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | kyshtovka
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | qaanaaq
# Processing Record 28 of Set 1 | ponta delgada
# Processing Record 29 of Set 1 | contamana
# Processing Record 30 of Set 1 | arraial do cabo
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | flinders
# Processing Record 33 of Set 1 | katsuura
# Processing Record 34 of Set 1 | grand gaube
# Processing Record 35 of Set 1 | norman wells
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | dong hoi
# Processing Record 38 of Set 1 | ozernovskiy
# Processing Record 39 of Set 1 | castro
# Processing Record 40 of Set 1 | bilibino
# Processing Record 41 of Set 1 | westport
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | buala
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | rosetta
# Processing Record 46 of Set 1 | baturite
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | spisska nova ves
# Processing Record 49 of Set 1 | saint-georges
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | kurumkan
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | abu ghosh
# Processing Record 4 of Set 2 | ratnagiri
# Processing Record 5 of Set 2 | neka
# Processing Record 6 of Set 2 | matao
# Processing Record 7 of Set 2 | saint-pierre
# Processing Record 8 of Set 2 | torbay
# Processing Record 9 of Set 2 | isabela
# Processing Record 10 of Set 2 | kodiak
# Processing Record 11 of Set 2 | usinsk
# Processing Record 12 of Set 2 | rockhampton
# Processing Record 13 of Set 2 | tarakan
# Processing Record 14 of Set 2 | bara
# Processing Record 15 of Set 2 | piterka
# Processing Record 16 of Set 2 | jamestown
# Processing Record 17 of Set 2 | guatire
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | zabid
# Processing Record 20 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 2 | longyearbyen
# Processing Record 22 of Set 2 | codrington
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | los llanos de aridane
# Processing Record 25 of Set 2 | uray
# Processing Record 26 of Set 2 | verkhnevilyuysk
# Processing Record 27 of Set 2 | vardo
# Processing Record 28 of Set 2 | esperance
# Processing Record 29 of Set 2 | tambura
# Processing Record 30 of Set 2 | albany
# Processing Record 31 of Set 2 | valdemarpils
# Processing Record 32 of Set 2 | port lincoln
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | khartoum
# Processing Record 35 of Set 2 | ankang
# Processing Record 36 of Set 2 | samfya
# Processing Record 37 of Set 2 | ornskoldsvik
# Processing Record 38 of Set 2 | tiksi
# Processing Record 39 of Set 2 | pombia
# Processing Record 40 of Set 2 | kalmunai
# Processing Record 41 of Set 2 | dakar
# Processing Record 42 of Set 2 | upernavik
# Processing Record 43 of Set 2 | tonj
# Processing Record 44 of Set 2 | leningradskiy
# Processing Record 45 of Set 2 | tromso
# Processing Record 46 of Set 2 | chokurdakh
# Processing Record 47 of Set 2 | atuona
# Processing Record 48 of Set 2 | hay river
# Processing Record 49 of Set 2 | alappuzha
# Processing Record 50 of Set 2 | atar
# Processing Record 1 of Set 3 | namatanai
# Processing Record 2 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 3 | lompoc
# Processing Record 4 of Set 3 | carnarvon
# Processing Record 5 of Set 3 | hermanus
# Processing Record 6 of Set 3 | vila franca do campo
# Processing Record 7 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 3 | margate
# Processing Record 9 of Set 3 | mahebourg
# Processing Record 10 of Set 3 | charagua
# Processing Record 11 of Set 3 | winnemucca
# Processing Record 12 of Set 3 | lagos
# Processing Record 13 of Set 3 | santander
# Processing Record 14 of Set 3 | ferrol
# Processing Record 15 of Set 3 | thompson
# Processing Record 16 of Set 3 | cam ranh
# Processing Record 17 of Set 3 | ovalle
# Processing Record 18 of Set 3 | vostok
# Processing Record 19 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 3 | saint-philippe
# Processing Record 21 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 3 | san cristobal
# Processing Record 23 of Set 3 | ejido
# Processing Record 24 of Set 3 | sri aman
# Processing Record 25 of Set 3 | nouadhibou
# Processing Record 26 of Set 3 | klaksvik
# Processing Record 27 of Set 3 | provideniya
# Processing Record 28 of Set 3 | yulara
# Processing Record 29 of Set 3 | solsvik
# City not found. Skipping...
# Processing Record 30 of Set 3 | talnakh
# Processing Record 31 of Set 3 | sitka
# Processing Record 32 of Set 3 | sambulawan
# Processing Record 33 of Set 3 | hamilton
# Processing Record 34 of Set 3 | adrar
# Processing Record 35 of Set 3 | luderitz
# Processing Record 36 of Set 3 | teavaro
# Processing Record 37 of Set 3 | severo-kurilsk
# Processing Record 38 of Set 3 | hualmay
# Processing Record 39 of Set 3 | cabra
# Processing Record 40 of Set 3 | sofiysk
# City not found. Skipping...
# Processing Record 41 of Set 3 | kaitangata
# Processing Record 42 of Set 3 | anadyr
# Processing Record 43 of Set 3 | bandarbeyla
# Processing Record 44 of Set 3 | tuatapere
# Processing Record 45 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 3 | olinda
# Processing Record 47 of Set 3 | raudeberg
# Processing Record 48 of Set 3 | saskylakh
# Processing Record 49 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 3 | kamaishi
# Processing Record 1 of Set 4 | umm lajj
# Processing Record 2 of Set 4 | hobart
# Processing Record 3 of Set 4 | lebu
# Processing Record 4 of Set 4 | sao filipe
# Processing Record 5 of Set 4 | north platte
# Processing Record 6 of Set 4 | manokwari
# Processing Record 7 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 4 | asyut
# Processing Record 9 of Set 4 | ambovombe
# Processing Record 10 of Set 4 | ponta do sol
# Processing Record 11 of Set 4 | vila
# Processing Record 12 of Set 4 | santiago de cuba
# Processing Record 13 of Set 4 | uberlandia
# Processing Record 14 of Set 4 | hithadhoo
# Processing Record 15 of Set 4 | pisco
# Processing Record 16 of Set 4 | camargo
# Processing Record 17 of Set 4 | russell
# Processing Record 18 of Set 4 | nemuro
# Processing Record 19 of Set 4 | gat
# Processing Record 20 of Set 4 | tukrah
# Processing Record 21 of Set 4 | raton
# Processing Record 22 of Set 4 | souillac
# Processing Record 23 of Set 4 | nizhneivkino
# Processing Record 24 of Set 4 | smithers
# Processing Record 25 of Set 4 | yermakovskoye
# Processing Record 26 of Set 4 | imisli
# City not found. Skipping...
# Processing Record 27 of Set 4 | sakiai
# Processing Record 28 of Set 4 | raga
# Processing Record 29 of Set 4 | bluff
# Processing Record 30 of Set 4 | geraldton
# Processing Record 31 of Set 4 | berlevag
# Processing Record 32 of Set 4 | tasiilaq
# Processing Record 33 of Set 4 | truckee
# Processing Record 34 of Set 4 | merritt island
# Processing Record 35 of Set 4 | sambava
# Processing Record 36 of Set 4 | khatanga
# Processing Record 37 of Set 4 | san patricio
# Processing Record 38 of Set 4 | pevek
# Processing Record 39 of Set 4 | lagoa
# Processing Record 40 of Set 4 | atasu
# Processing Record 41 of Set 4 | xining
# Processing Record 42 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 43 of Set 4 | rawson
# Processing Record 44 of Set 4 | sao jose da coroa grande
# Processing Record 45 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 4 | isangel
# Processing Record 47 of Set 4 | constitucion
# Processing Record 48 of Set 4 | barrow
# Processing Record 49 of Set 4 | khovu-aksy
# Processing Record 50 of Set 4 | klyuchi
# Processing Record 1 of Set 5 | itapirapua
# Processing Record 2 of Set 5 | tomatlan
# Processing Record 3 of Set 5 | barcelos
# Processing Record 4 of Set 5 | fort frances
# Processing Record 5 of Set 5 | chuy
# Processing Record 6 of Set 5 | saulkrasti
# Processing Record 7 of Set 5 | kahului
# Processing Record 8 of Set 5 | sisimiut
# Processing Record 9 of Set 5 | ambikapur
# Processing Record 10 of Set 5 | narsaq
# Processing Record 11 of Set 5 | cidreira
# Processing Record 12 of Set 5 | deputatskiy
# Processing Record 13 of Set 5 | ankpa
# Processing Record 14 of Set 5 | zavetnoye
# Processing Record 15 of Set 5 | manzhouli
# Processing Record 16 of Set 5 | hovd
# Processing Record 17 of Set 5 | caucaia
# Processing Record 18 of Set 5 | vallenar
# Processing Record 19 of Set 5 | taoudenni
# Processing Record 20 of Set 5 | turukhansk
# Processing Record 21 of Set 5 | rosarito
# Processing Record 22 of Set 5 | razdolinsk
# Processing Record 23 of Set 5 | maarianhamina
# Processing Record 24 of Set 5 | korla
# Processing Record 25 of Set 5 | mar del plata
# Processing Record 26 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 5 | junction city
# Processing Record 28 of Set 5 | laguna
# Processing Record 29 of Set 5 | mount isa
# Processing Record 30 of Set 5 | muscat
# Processing Record 31 of Set 5 | ask
# Processing Record 32 of Set 5 | aswan
# Processing Record 33 of Set 5 | sobolevo
# Processing Record 34 of Set 5 | zhigansk
# Processing Record 35 of Set 5 | quatre cocos
# Processing Record 36 of Set 5 | makakilo city
# Processing Record 37 of Set 5 | gwadar
# Processing Record 38 of Set 5 | batemans bay
# Processing Record 39 of Set 5 | alice springs
# Processing Record 40 of Set 5 | imbituba
# Processing Record 41 of Set 5 | ribeira grande
# Processing Record 42 of Set 5 | dingle
# Processing Record 43 of Set 5 | huangchuan
# Processing Record 44 of Set 5 | moyale
# Processing Record 45 of Set 5 | kalat
# Processing Record 46 of Set 5 | hofn
# Processing Record 47 of Set 5 | coihaique
# Processing Record 48 of Set 5 | solnechnyy
# Processing Record 49 of Set 5 | iqaluit
# Processing Record 50 of Set 5 | chicama
# Processing Record 1 of Set 6 | kampong thum
# Processing Record 2 of Set 6 | tazovskiy
# Processing Record 3 of Set 6 | yambio
# Processing Record 4 of Set 6 | alekseyevsk
# Processing Record 5 of Set 6 | hare bay
# Processing Record 6 of Set 6 | ust-omchug
# Processing Record 7 of Set 6 | bekhteyevka
# Processing Record 8 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 6 | namibe
# Processing Record 10 of Set 6 | muktagachha
# City not found. Skipping...
# Processing Record 11 of Set 6 | ancud
# Processing Record 12 of Set 6 | forio
# Processing Record 13 of Set 6 | saldanha
# Processing Record 14 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 6 | sarangani
# Processing Record 16 of Set 6 | lucapa
# Processing Record 17 of Set 6 | te anau
# Processing Record 18 of Set 6 | kissidougou
# Processing Record 19 of Set 6 | port macquarie
# Processing Record 20 of Set 6 | nanjing
# Processing Record 21 of Set 6 | sena madureira
# Processing Record 22 of Set 6 | gasa
# Processing Record 23 of Set 6 | nikolskoye
# Processing Record 24 of Set 6 | victoria
# Processing Record 25 of Set 6 | nacala
# Processing Record 26 of Set 6 | samarai
# Processing Record 27 of Set 6 | airai
# Processing Record 28 of Set 6 | andros town
# Processing Record 29 of Set 6 | moron
# Processing Record 30 of Set 6 | doka
# Processing Record 31 of Set 6 | rabaul
# Processing Record 32 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 6 | san lorenzo
# Processing Record 34 of Set 6 | ostrovnoy
# Processing Record 35 of Set 6 | blythe
# Processing Record 36 of Set 6 | suhindol
# Processing Record 37 of Set 6 | bubaque
# Processing Record 38 of Set 6 | kerteh
# City not found. Skipping...
# Processing Record 39 of Set 6 | paamiut
# Processing Record 40 of Set 6 | santa maria
# Processing Record 41 of Set 6 | xinmin
# Processing Record 42 of Set 6 | okulovka
# Processing Record 43 of Set 6 | praia
# Processing Record 44 of Set 6 | kommunar
# Processing Record 45 of Set 6 | sur
# Processing Record 46 of Set 6 | sola
# Processing Record 47 of Set 6 | kloulklubed
# Processing Record 48 of Set 6 | jatai
# Processing Record 49 of Set 6 | alghero
# Processing Record 50 of Set 6 | nantucket
# Processing Record 1 of Set 7 | storforshei
# Processing Record 2 of Set 7 | conakry
# Processing Record 3 of Set 7 | pestravka
# Processing Record 4 of Set 7 | port hardy
# Processing Record 5 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 7 | stornoway
# Processing Record 7 of Set 7 | haveli
# Processing Record 8 of Set 7 | savinka
# Processing Record 9 of Set 7 | djougou
# Processing Record 10 of Set 7 | mana
# Processing Record 11 of Set 7 | havoysund
# Processing Record 12 of Set 7 | binzhou
# Processing Record 13 of Set 7 | sorong
# Processing Record 14 of Set 7 | itarema
# Processing Record 15 of Set 7 | sao joao da barra
# Processing Record 16 of Set 7 | veraval
# Processing Record 17 of Set 7 | abu dhabi
# Processing Record 18 of Set 7 | puerto escondido
# Processing Record 19 of Set 7 | paracale
# Processing Record 20 of Set 7 | itoman
# Processing Record 21 of Set 7 | kruisfontein
# Processing Record 22 of Set 7 | cine
# Processing Record 23 of Set 7 | siocon
# Processing Record 24 of Set 7 | moose factory
# Processing Record 25 of Set 7 | nambiyur
# Processing Record 26 of Set 7 | staryy nadym
# Processing Record 27 of Set 7 | araouane
# Processing Record 28 of Set 7 | tynda
# Processing Record 29 of Set 7 | goderich
# Processing Record 30 of Set 7 | faanui
# Processing Record 31 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 7 | poso
# Processing Record 33 of Set 7 | port hedland
# Processing Record 34 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 7 | taltal
# Processing Record 36 of Set 7 | tembisa
# Processing Record 37 of Set 7 | bauchi
# Processing Record 38 of Set 7 | san pedro
# Processing Record 39 of Set 7 | sindand
# City not found. Skipping...
# Processing Record 40 of Set 7 | shache
# Processing Record 41 of Set 7 | ashoknagar
# Processing Record 42 of Set 7 | zlobin
# Processing Record 43 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 44 of Set 7 | tiarei
# Processing Record 45 of Set 7 | rocha
# Processing Record 46 of Set 7 | copiapo
# Processing Record 47 of Set 7 | falam
# Processing Record 48 of Set 7 | kendari
# Processing Record 49 of Set 7 | sept-iles
# Processing Record 50 of Set 7 | palatka
# Processing Record 1 of Set 8 | ilhabela
# Processing Record 2 of Set 8 | dudinka
# Processing Record 3 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 8 | gao
# Processing Record 5 of Set 8 | egvekinot
# Processing Record 6 of Set 8 | kavieng
# Processing Record 7 of Set 8 | abu kamal
# Processing Record 8 of Set 8 | olafsvik
# Processing Record 9 of Set 8 | dickinson
# Processing Record 10 of Set 8 | kieta
# Processing Record 11 of Set 8 | knysna
# Processing Record 12 of Set 8 | kawalu
# Processing Record 13 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 14 of Set 8 | santa catarina de tepehuanes
# Processing Record 15 of Set 8 | ciudad guayana
# Processing Record 16 of Set 8 | ballina
# Processing Record 17 of Set 8 | guasdualito
# Processing Record 18 of Set 8 | kavaratti
# Processing Record 19 of Set 8 | wamba
# Processing Record 20 of Set 8 | venado tuerto
# Processing Record 21 of Set 8 | otsuki
# Processing Record 22 of Set 8 | byumba
# Processing Record 23 of Set 8 | wanning
# Processing Record 24 of Set 8 | abalak
# Processing Record 25 of Set 8 | chiang klang
# Processing Record 26 of Set 8 | lincoln
# Processing Record 27 of Set 8 | tautira
# Processing Record 28 of Set 8 | huatulco
# Processing Record 29 of Set 8 | faya
# Processing Record 30 of Set 8 | davila
# Processing Record 31 of Set 8 | jumla
# Processing Record 32 of Set 8 | mayskiy
# Processing Record 33 of Set 8 | sorland
# Processing Record 34 of Set 8 | marfino
# Processing Record 35 of Set 8 | tashla
# Processing Record 36 of Set 8 | port elizabeth
# Processing Record 37 of Set 8 | srednekolymsk
# Processing Record 38 of Set 8 | tessalit
# Processing Record 39 of Set 8 | saint george
# Processing Record 40 of Set 8 | cockburn town
# Processing Record 41 of Set 8 | belle fourche
# Processing Record 42 of Set 8 | batagay
# Processing Record 43 of Set 8 | ocean springs
# Processing Record 44 of Set 8 | libreville
# Processing Record 45 of Set 8 | la mana
# Processing Record 46 of Set 8 | hambantota
# Processing Record 47 of Set 8 | aklavik
# Processing Record 48 of Set 8 | husavik
# Processing Record 49 of Set 8 | tibati
# Processing Record 50 of Set 8 | tilichiki
# Processing Record 1 of Set 9 | san felipe
# Processing Record 2 of Set 9 | umtata
# Processing Record 3 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 9 | manado
# Processing Record 5 of Set 9 | sarkand
# Processing Record 6 of Set 9 | mgandu
# Processing Record 7 of Set 9 | arica
# Processing Record 8 of Set 9 | nyurba
# Processing Record 9 of Set 9 | batticaloa
# Processing Record 10 of Set 9 | banda aceh
# Processing Record 11 of Set 9 | rajgarh
# Processing Record 12 of Set 9 | zhuhai
# Processing Record 13 of Set 9 | talkha
# Processing Record 14 of Set 9 | shar
# Processing Record 15 of Set 9 | una
# Processing Record 16 of Set 9 | orlik
# Processing Record 17 of Set 9 | touros
# Processing Record 18 of Set 9 | jinchengjiang
# City not found. Skipping...
# Processing Record 19 of Set 9 | huilong
# Processing Record 20 of Set 9 | ust-maya
# Processing Record 21 of Set 9 | mehamn
# Processing Record 22 of Set 9 | roald
# Processing Record 23 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 24 of Set 9 | avera
# Processing Record 25 of Set 9 | san quintin
# Processing Record 26 of Set 9 | baglan
# Processing Record 27 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 9 | purna
# Processing Record 29 of Set 9 | ibotirama
# Processing Record 30 of Set 9 | teguldet
# Processing Record 31 of Set 9 | zyryanka
# Processing Record 32 of Set 9 | samana
# Processing Record 33 of Set 9 | lynn haven
# Processing Record 34 of Set 9 | clyde river
# Processing Record 35 of Set 9 | vao
# Processing Record 36 of Set 9 | mangrol
# Processing Record 37 of Set 9 | yar-sale
# Processing Record 38 of Set 9 | camana
# Processing Record 39 of Set 9 | lillehammer
# Processing Record 40 of Set 9 | koumac
# Processing Record 41 of Set 9 | palmer
# Processing Record 42 of Set 9 | ust-uda
# Processing Record 43 of Set 9 | ust-kuyga
# Processing Record 44 of Set 9 | cabo san lucas
# Processing Record 45 of Set 9 | port-gentil
# Processing Record 46 of Set 9 | vila velha
# Processing Record 47 of Set 9 | harper
# Processing Record 48 of Set 9 | boden
# Processing Record 49 of Set 9 | viedma
# Processing Record 50 of Set 9 | guabito
# Processing Record 1 of Set 10 | sawtell
# Processing Record 2 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 3 of Set 10 | yanam
# Processing Record 4 of Set 10 | puerto lumbreras
# Processing Record 5 of Set 10 | magdagachi
# Processing Record 6 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 7 of Set 10 | ust-tsilma
# Processing Record 8 of Set 10 | meulaboh
# Processing Record 9 of Set 10 | chapais
# Processing Record 10 of Set 10 | sechura
# Processing Record 11 of Set 10 | shestakovo
# Processing Record 12 of Set 10 | bemidji
# Processing Record 13 of Set 10 | pishva
# Processing Record 14 of Set 10 | zonalnoye
# City not found. Skipping...
# Processing Record 15 of Set 10 | portland
# Processing Record 16 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 17 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 18 of Set 10 | calderitas
# Processing Record 19 of Set 10 | kuusamo
# Processing Record 20 of Set 10 | sulangan
# Processing Record 21 of Set 10 | broken hill
# Processing Record 22 of Set 10 | coquimbo
# Processing Record 23 of Set 10 | lavrentiya
# Processing Record 24 of Set 10 | santo antonio do monte
# Processing Record 25 of Set 10 | miandrivazo
# Processing Record 26 of Set 10 | tutin
# Processing Record 27 of Set 10 | lamu
# Processing Record 28 of Set 10 | nishihara
# Processing Record 29 of Set 10 | broome
# Processing Record 30 of Set 10 | novobirilyussy
# Processing Record 31 of Set 10 | byron bay
# Processing Record 32 of Set 10 | jaisalmer
# Processing Record 33 of Set 10 | qaqortoq
# Processing Record 34 of Set 10 | strezhevoy
# Processing Record 35 of Set 10 | monte escobedo
# Processing Record 36 of Set 10 | tome-acu
# City not found. Skipping...
# Processing Record 37 of Set 10 | itaporanga
# Processing Record 38 of Set 10 | mareeba
# Processing Record 39 of Set 10 | burica
# City not found. Skipping...
# Processing Record 40 of Set 10 | asau
# Processing Record 41 of Set 10 | tupik
# Processing Record 42 of Set 10 | charters towers
# Processing Record 43 of Set 10 | lata
# Processing Record 44 of Set 10 | matara
# Processing Record 45 of Set 10 | visby
# Processing Record 46 of Set 10 | high level
# Processing Record 47 of Set 10 | mehendiganj
# Processing Record 48 of Set 10 | nuuk
# Processing Record 49 of Set 10 | noumea
# Processing Record 50 of Set 10 | ilulissat
# Processing Record 1 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 11 | conceicao do araguaia
# Processing Record 3 of Set 11 | nome
# Processing Record 4 of Set 11 | bambous virieux
# Processing Record 5 of Set 11 | lusambo
# Processing Record 6 of Set 11 | oriximina
# Processing Record 7 of Set 11 | abu samrah
# Processing Record 8 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 11 | saint-augustin
# Processing Record 10 of Set 11 | peyima
# Processing Record 11 of Set 11 | zhangye
# Processing Record 12 of Set 11 | atsiki
# City not found. Skipping...
# Processing Record 13 of Set 11 | kushiro
# Processing Record 14 of Set 11 | motala
# Processing Record 15 of Set 11 | bossangoa
# Processing Record 16 of Set 11 | soyo
# Processing Record 17 of Set 11 | mastic beach
# Processing Record 18 of Set 11 | biltine
# Processing Record 19 of Set 11 | ulladulla
# Processing Record 20 of Set 11 | imuris
# Processing Record 21 of Set 11 | areosa
# Processing Record 22 of Set 11 | igarka
# Processing Record 23 of Set 11 | halifax
# Processing Record 24 of Set 11 | baghdad
# Processing Record 25 of Set 11 | fortuna
# Processing Record 26 of Set 11 | koulikoro
# Processing Record 27 of Set 11 | bardiyah
# Processing Record 28 of Set 11 | beian
# Processing Record 29 of Set 11 | pesochnyy
# Processing Record 30 of Set 11 | lasa
# Processing Record 31 of Set 11 | cap-aux-meules
# Processing Record 32 of Set 11 | libertador general san martin
# Processing Record 33 of Set 11 | catuday
# Processing Record 34 of Set 11 | el faiyum
# City not found. Skipping...
# Processing Record 35 of Set 11 | honningsvag
# Processing Record 36 of Set 11 | yingshang
# City not found. Skipping...
# Processing Record 37 of Set 11 | tambopata
# Processing Record 38 of Set 11 | mongoumba
# Processing Record 39 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 11 | bagdarin
# Processing Record 41 of Set 11 | fandriana
# Processing Record 42 of Set 11 | sabha
# Processing Record 43 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 44 of Set 11 | magnolia
# Processing Record 45 of Set 11 | newtownards
# Processing Record 46 of Set 11 | limoges
# Processing Record 47 of Set 11 | mozarlandia
# Processing Record 48 of Set 11 | grand forks
# Processing Record 49 of Set 11 | mbumi
# Processing Record 50 of Set 11 | marawi
# Processing Record 1 of Set 12 | laiagam
# City not found. Skipping...
# Processing Record 2 of Set 12 | ambilobe
# Processing Record 3 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 4 of Set 12 | uppiliapuram
# City not found. Skipping...
# Processing Record 5 of Set 12 | huarmey
# Processing Record 6 of Set 12 | laohekou
# Processing Record 7 of Set 12 | shubarshi
# Processing Record 8 of Set 12 | hasaki
# Processing Record 9 of Set 12 | takoradi
# Processing Record 10 of Set 12 | sibolga
# Processing Record 11 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 12 of Set 12 | safaga
# Processing Record 13 of Set 12 | hami
# Processing Record 14 of Set 12 | prescott
# Processing Record 15 of Set 12 | auchterarder
# Processing Record 16 of Set 12 | canutama
# Processing Record 17 of Set 12 | alofi
# Processing Record 18 of Set 12 | garowe
# Processing Record 19 of Set 12 | anchorage
# Processing Record 20 of Set 12 | tambul
# City not found. Skipping...
# Processing Record 21 of Set 12 | padang
# Processing Record 22 of Set 12 | simpang
# Processing Record 23 of Set 12 | vytegra
# Processing Record 24 of Set 12 | dunedin
# Processing Record 25 of Set 12 | gawler
# Processing Record 26 of Set 12 | sackville
# Processing Record 27 of Set 12 | svetlogorsk
# Processing Record 28 of Set 12 | laurel
# Processing Record 29 of Set 12 | kastamonu
# Processing Record 30 of Set 12 | fairbanks
# Processing Record 31 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 12 | san carlos
# Processing Record 33 of Set 12 | mayumba
# Processing Record 34 of Set 12 | cabo rojo
# Processing Record 35 of Set 12 | mandalgovi
# Processing Record 36 of Set 12 | copperas cove
# Processing Record 37 of Set 12 | gandorhun
# Processing Record 38 of Set 12 | slobozia-ciorasti
# Processing Record 39 of Set 12 | tigil
# Processing Record 40 of Set 12 | akyab
# Processing Record 41 of Set 12 | waingapu
# Processing Record 42 of Set 12 | panjab
# Processing Record 43 of Set 12 | iwanai
# Processing Record 44 of Set 12 | robertsport
# Processing Record 45 of Set 12 | bairiki
# Processing Record 46 of Set 12 | arman
# Processing Record 47 of Set 12 | marsa matruh
# Processing Record 48 of Set 12 | henties bay
# Processing Record 49 of Set 12 | mount gambier
# Processing Record 50 of Set 12 | hohhot
# Processing Record 1 of Set 13 | san vicente
# Processing Record 2 of Set 13 | pangnirtung
# Processing Record 3 of Set 13 | huicungo
# Processing Record 4 of Set 13 | chumphon
# Processing Record 5 of Set 13 | zgierz
# Processing Record 6 of Set 13 | olga
# Processing Record 7 of Set 13 | tinskoy
# Processing Record 8 of Set 13 | sabang
# Processing Record 9 of Set 13 | santa rosa
# Processing Record 10 of Set 13 | beringovskiy
# Processing Record 11 of Set 13 | antofagasta
# Processing Record 12 of Set 13 | niono
# Processing Record 13 of Set 13 | vangaindrano
# Processing Record 14 of Set 13 | vigrestad
# Processing Record 15 of Set 13 | kasongo-lunda
# Processing Record 16 of Set 13 | wani
# Processing Record 17 of Set 13 | karpogory
# Processing Record 18 of Set 13 | cassilandia
# Processing Record 19 of Set 13 | male
# Processing Record 20 of Set 13 | malkangiri
# Processing Record 21 of Set 13 | hobyo
# Processing Record 22 of Set 13 | iberia
# Processing Record 23 of Set 13 | matay
# Processing Record 24 of Set 13 | bougouni
# Processing Record 25 of Set 13 | brae
# Processing Record 26 of Set 13 | port augusta
# Processing Record 27 of Set 13 | kamenka
# Processing Record 28 of Set 13 | marzuq
# Processing Record 29 of Set 13 | roebourne
# Processing Record 30 of Set 13 | nanton
# Processing Record 31 of Set 13 | darhan
# Processing Record 32 of Set 13 | kungurtug
# Processing Record 33 of Set 13 | saint simons
# Processing Record 34 of Set 13 | pedasi
# Processing Record 35 of Set 13 | santa elena
# Processing Record 36 of Set 13 | puerto leguizamo
# Processing Record 37 of Set 13 | platanos
# Processing Record 38 of Set 13 | homer
# Processing Record 39 of Set 13 | gornyy
# Processing Record 40 of Set 13 | lekoni
# Processing Record 41 of Set 13 | mikhaylovka
# Processing Record 42 of Set 13 | awjilah
# Processing Record 43 of Set 13 | puerto madryn
# Processing Record 44 of Set 13 | irara
# Processing Record 45 of Set 13 | the valley
# Processing Record 46 of Set 13 | haines junction
# Processing Record 47 of Set 13 | carauari
# Processing Record 48 of Set 13 | gazli
# Processing Record 49 of Set 13 | lufilufi
# Processing Record 50 of Set 13 | pitimbu
# Processing Record 1 of Set 14 | balaipungut
# Processing Record 2 of Set 14 | novo aripuana
# Processing Record 3 of Set 14 | sortland
# Processing Record 4 of Set 14 | zunyi
# Processing Record 5 of Set 14 | tyrma
# Processing Record 6 of Set 14 | grindavik
# Processing Record 7 of Set 14 | karratha
# Processing Record 8 of Set 14 | passage west
# Processing Record 9 of Set 14 | flin flon
# Processing Record 10 of Set 14 | hokitika
# Processing Record 11 of Set 14 | tonala
# Processing Record 12 of Set 14 | nizwa
# Processing Record 13 of Set 14 | kanniyakumari
# Processing Record 14 of Set 14 | kapit
# Processing Record 15 of Set 14 | uniontown
# Processing Record 16 of Set 14 | wewak
# Processing Record 17 of Set 14 | qorveh
# Processing Record 18 of Set 14 | nabire
# Processing Record 19 of Set 14 | mrakovo
# Processing Record 20 of Set 14 | teacapan
# Processing Record 21 of Set 14 | berdigestyakh
# Processing Record 22 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 14 | troitskoye
# Processing Record 24 of Set 14 | bloemhof
# Processing Record 25 of Set 14 | nara
# Processing Record 26 of Set 14 | cayenne
# Processing Record 27 of Set 14 | rabo de peixe
# Processing Record 28 of Set 14 | pauini
# Processing Record 29 of Set 14 | barkhan
# Processing Record 30 of Set 14 | baruun-urt
# Processing Record 31 of Set 14 | ouro preto do oeste
# Processing Record 32 of Set 14 | vanimo
# Processing Record 33 of Set 14 | santa ana
# Processing Record 34 of Set 14 | vanavara
# Processing Record 35 of Set 14 | saint anthony
# Processing Record 36 of Set 14 | saint andrews
# Processing Record 37 of Set 14 | lakes entrance
# Processing Record 38 of Set 14 | severodvinsk
# Processing Record 39 of Set 14 | vastervik
# City not found. Skipping...
# Processing Record 40 of Set 14 | lorengau
# Processing Record 41 of Set 14 | sherbrooke
# Processing Record 42 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 43 of Set 14 | skovorodino
# Processing Record 44 of Set 14 | saint-alexandre
# Processing Record 45 of Set 14 | alihe
# Processing Record 46 of Set 14 | ha giang
# Processing Record 47 of Set 14 | dondo
# Processing Record 48 of Set 14 | redmond
# Processing Record 49 of Set 14 | krasnyy chikoy
# Processing Record 50 of Set 14 | jawhar
# Processing Record 1 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 2 of Set 15 | yongan
# Processing Record 3 of Set 15 | sinnamary
# Processing Record 4 of Set 15 | oranjemund
# Processing Record 5 of Set 15 | madang
# Processing Record 6 of Set 15 | honiara
# Processing Record 7 of Set 15 | sao gabriel da cachoeira
# Processing Record 8 of Set 15 | syzran
# Processing Record 9 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 15 | tsnori
# Processing Record 11 of Set 15 | logrono
# Processing Record 12 of Set 15 | skibbereen
# Processing Record 13 of Set 15 | funadhoo
# Processing Record 14 of Set 15 | steamboat springs
# Processing Record 15 of Set 15 | nador
# Processing Record 16 of Set 15 | axim
# Processing Record 17 of Set 15 | progreso
# Processing Record 18 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 15 | escarcega
# Processing Record 20 of Set 15 | puri
# Processing Record 21 of Set 15 | kjopsvik
# Processing Record 22 of Set 15 | gayeri
# Processing Record 23 of Set 15 | miri
# Processing Record 24 of Set 15 | kropotkin
# Processing Record 25 of Set 15 | birjand
# Processing Record 26 of Set 15 | maracaju
# Processing Record 27 of Set 15 | buchanan
# Processing Record 28 of Set 15 | paris
# Processing Record 29 of Set 15 | boa vista
# Processing Record 30 of Set 15 | qarqin
# Processing Record 31 of Set 15 | kindu
# Processing Record 32 of Set 15 | kutoarjo
# Processing Record 33 of Set 15 | brewster
# Processing Record 34 of Set 15 | ugoofaaru
# Processing Record 35 of Set 15 | tierralta
# Processing Record 36 of Set 15 | xiaoshi
# Processing Record 37 of Set 15 | meadow lake
# Processing Record 38 of Set 15 | otavi
# Processing Record 39 of Set 15 | clara
# Processing Record 40 of Set 15 | kabardinka
# Processing Record 41 of Set 15 | kurilsk
# Processing Record 42 of Set 15 | benguela
# Processing Record 43 of Set 15 | bad doberan
# Processing Record 44 of Set 15 | labuhan
# Processing Record 45 of Set 15 | hirara
# Processing Record 46 of Set 15 | saint-joseph
# Processing Record 47 of Set 15 | muli
# Processing Record 48 of Set 15 | comodoro rivadavia
# Processing Record 49 of Set 15 | fare
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ushuaia      AR -54.8000  -68.3000     53.26        71          40
# 1     Yellowknife      CA  62.4560 -114.3525    -17.88        76          90
# 2        Cherskiy      RU  68.7500  161.3000    -24.57        95         100
# 3           Muros      ES  42.7762   -9.0603     51.24        94          23
# 4          Dikson      RU  73.5069   80.5464    -23.64        94          92
# 5  Guerrero Negro      MX  27.9769 -114.0611     63.32        46           0
# 6     Gorom-Gorom      BF  14.4439   -0.2361     68.54        17          35
# 7         Rikitea      PF -23.1203 -134.9692     77.47        76         100
# 8          Avarua      CK -21.2078 -159.7750     82.45        61          75
# 9       Bonavista      CA  48.6499  -53.1147     30.11        81         100
#
#    Wind Speed Current Description
# 0       24.16    scattered clouds
# 1        4.61   light shower snow
# 2        1.63     overcast clouds
# 3        5.73          few clouds
# 4        6.62     overcast clouds
# 5       18.48           clear sky
# 6       10.65    scattered clouds
# 7       12.57       moderate rain
# 8       11.50       broken clouds
# 9       38.48     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
